# %% [markdown]
# ####**RESULTADOS LABEL FLIPPING**: Resultados para los tres conjuntos de datos

# %%
# !pip install SciencePlots

# %% [markdown]
# **MNIST**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import scienceplots

mpl.rcParams.update({
    'font.size': 18,
    'axes.titlesize': 18,
    'axes.labelsize': 18,
    'xtick.labelsize': 18,
    'ytick.labelsize': 18,
    'legend.fontsize': 18,
})

df1 = pd.read_csv('metrics_DP_LP_mnist.csv')
df2 = pd.read_csv('metrics_DP_Static_mnist.csv')

rondas = df1['Round']
accuracies_lp = df1['Accuracy (%)']
epsilon_cummulative_lp= df1['Epsilon Acumulado']

accuracies_static = df2['Accuracy (%)']
epsilon_cummulative_static = df2['Epsilon Acumulado']

plt.style.use(['science', 'no-latex'])
fig, ax1 = plt.subplots(figsize=(8, 5))

color1 = 'C1'
color2 = 'C0'
ax1.set_xlabel('Rondas')
ax1.set_ylabel('Accuracy (%) / Epsilon', color='black')
ln1 = ax1.plot(rondas, accuracies_lp, color=color1, label='Accuracy (%)', linewidth=2)
ln2 = ax1.plot(rondas, epsilon_cummulative_lp, color=color1, label='Epsilon acumulado', linestyle='--', linewidth=2)
ln3 = ax1.plot(rondas, accuracies_static, color=color2, label='Accuracy (%)', linewidth=2)
ln4 = ax1.plot(rondas, epsilon_cummulative_static, color=color2, label='Epsilon acumulado', linestyle='--', linewidth=2)
ax1.tick_params(axis='y', labelcolor='black')
ax1.set_ylim(0, 100)

lines = ln1 + ln3
labels = ["PD Optimizada", "PD Estatica"]
ax1.legend(lines, labels, loc='best')

fig.tight_layout()
plt.grid(True)
plt.savefig('LabelFlipping_MNIST.png', dpi=300)

# %% [markdown]
# **FashionMNIST**

# %%
df1 = pd.read_csv('metrics_DP_LP_fashion.csv')
df2 = pd.read_csv('metrics_DP_Static_fashion.csv')

rondas = df1['Round']
accuracies_lp = df1['Accuracy (%)']
epsilon_cummulative_lp= df1['Epsilon Acumulado']

accuracies_static = df2['Accuracy (%)']
epsilon_cummulative_static = df2['Epsilon Acumulado']

plt.style.use(['science', 'no-latex'])
fig, ax1 = plt.subplots(figsize=(8, 5))

color1 = 'C1'
color2 = 'C0'
ax1.set_xlabel('Rondas')
ax1.set_ylabel('Accuracy (%) / Epsilon', color='black')
ln1 = ax1.plot(rondas, accuracies_lp, color=color1, label='Accuracy (%)', linewidth=2)
ln2 = ax1.plot(rondas, epsilon_cummulative_lp, color=color1, label='Epsilon acumulado', linestyle='--', linewidth=2)
ln3 = ax1.plot(rondas, accuracies_static, color=color2, label='Accuracy (%)', linewidth=2)
ln4 = ax1.plot(rondas, epsilon_cummulative_static, color=color2, label='Epsilon acumulado', linestyle='--', linewidth=2)
ax1.tick_params(axis='y', labelcolor='black')
ax1.set_ylim(0, 100)

lines = ln1 + ln3
labels = ["PD Optimizada", "PD Estatica"]
ax1.legend(lines, labels, loc='best')

fig.tight_layout()
plt.grid(True)
plt.savefig('LabelFlipping_fashion.png', dpi=300)

# %% [markdown]
# **CIFAR-10**

# %%
df1 = pd.read_csv('metrics_DP_LP_cifar.csv')
df2 = pd.read_csv('metrics_DP_Static_cifar.csv')

rondas = df1['Round']
accuracies_lp = df1['Accuracy (%)']
epsilon_cummulative_lp= df1['Epsilon Acumulado']

accuracies_static = df2['Accuracy (%)']
epsilon_cummulative_static = df2['Epsilon Acumulado']

plt.style.use(['science', 'no-latex'])
fig, ax1 = plt.subplots(figsize=(8, 5))

color1 = 'C1'
color2 = 'C0'
ax1.set_xlabel('Rondas')
ax1.set_ylabel('Accuracy (%) / Epsilon', color='black')
ln1 = ax1.plot(rondas, accuracies_lp, color=color1, label='Accuracy (%)', linewidth=2)
ln2 = ax1.plot(rondas, epsilon_cummulative_lp, color=color1, label='Epsilon acumulado', linestyle='--', linewidth=2)
ln3 = ax1.plot(rondas, accuracies_static, color=color2, label='Accuracy (%)', linewidth=2)
ln4 = ax1.plot(rondas, epsilon_cummulative_static, color=color2, label='Epsilon acumulado', linestyle='--', linewidth=2)
ax1.tick_params(axis='y', labelcolor='black')
ax1.set_ylim(0, 100)

lines = ln1 + ln3
labels = ["PD Optimizada", "PD Estatica"]
ax1.legend(lines, labels, loc='best')

fig.tight_layout()
plt.grid(True)
plt.savefig('LabelFlipping_CIFAR.png', dpi=300)

# %% [markdown]
# ####**RESULTADOS GAUSSIAN**: Resultados para los tres conjuntos de datos

# %% [markdown]
# **MNIST**

# %%
df1 = pd.read_csv('metrics_DP_LP_mnist.csv')
df2 = pd.read_csv('metrics_DP_Static_mnist.csv')

rondas = df1['Round']
accuracies_lp = df1['Accuracy (%)']
epsilon_cummulative_lp= df1['Epsilon Acumulado']

accuracies_static = df2['Accuracy (%)']
epsilon_cummulative_static = df2['Epsilon Acumulado']

plt.style.use(['science', 'no-latex'])
fig, ax1 = plt.subplots(figsize=(8, 5))

color1 = 'C2'
color2 = 'C0'
ax1.set_xlabel('Rondas')
ax1.set_ylabel('Accuracy (%) / Epsilon', color='black')
ln1 = ax1.plot(rondas, accuracies_lp, color=color1, label='Accuracy (%)', linewidth=2)
ln2 = ax1.plot(rondas, epsilon_cummulative_lp, color=color1, label='Epsilon acumulado', linestyle='--', linewidth=2)
ln3 = ax1.plot(rondas, accuracies_static, color=color2, label='Accuracy (%)', linewidth=2)
ln4 = ax1.plot(rondas, epsilon_cummulative_static, color=color2, label='Epsilon acumulado', linestyle='--', linewidth=2)
ax1.tick_params(axis='y', labelcolor='black')
ax1.set_ylim(0, 100)

lines = ln1 + ln3
labels = ["PD Optimizada", "PD Estatica"]
ax1.legend(lines, labels, loc='best')

fig.tight_layout()
plt.grid(True)
plt.savefig('Gaussian_MNIST.png', dpi=300)

# %% [markdown]
# **FashionMNIST**

# %%
df1 = pd.read_csv('metrics_DP_LP_fashion.csv')
df2 = pd.read_csv('metrics_DP_Static_fashion.csv')

rondas = df1['Round']
accuracies_lp = df1['Accuracy (%)']
epsilon_cummulative_lp= df1['Epsilon Acumulado']

accuracies_static = df2['Accuracy (%)']
epsilon_cummulative_static = df2['Epsilon Acumulado']

plt.style.use(['science', 'no-latex'])
fig, ax1 = plt.subplots(figsize=(8, 5))

color1 = 'C2'
color2 = 'C0'
ax1.set_xlabel('Rondas')
ax1.set_ylabel('Accuracy (%) / Epsilon', color='black')
ln1 = ax1.plot(rondas, accuracies_lp, color=color1, label='Accuracy (%)', linewidth=2)
ln2 = ax1.plot(rondas, epsilon_cummulative_lp, color=color1, label='Epsilon acumulado', linestyle='--', linewidth=2)
ln3 = ax1.plot(rondas, accuracies_static, color=color2, label='Accuracy (%)', linewidth=2)
ln4 = ax1.plot(rondas, epsilon_cummulative_static, color=color2, label='Epsilon acumulado', linestyle='--', linewidth=2)
ax1.tick_params(axis='y', labelcolor='black')
ax1.set_ylim(0, 100)

lines = ln1 + ln3
labels = ["PD Optimizada", "PD Estatica"]
ax1.legend(lines, labels, loc='best')

fig.tight_layout()
plt.grid(True)
plt.savefig('Gaussian_fashion.png', dpi=300)

# %% [markdown]
# **CIFAR-10**

# %%
df1 = pd.read_csv('metrics_DP_LP_cifar.csv')
df2 = pd.read_csv('metrics_DP_Static_cifar.csv')

rondas = df1['Round']
accuracies_lp = df1['Accuracy (%)']
epsilon_cummulative_lp= df1['Epsilon Acumulado']

accuracies_static = df2['Accuracy (%)']
epsilon_cummulative_static = df2['Epsilon Acumulado']

plt.style.use(['science', 'no-latex'])
fig, ax1 = plt.subplots(figsize=(8, 5))

color1 = 'C2'
color2 = 'C0'
ax1.set_xlabel('Rondas')
ax1.set_ylabel('Accuracy (%) / Epsilon', color='black')
ln1 = ax1.plot(rondas, accuracies_lp, color=color1, label='Accuracy (%)', linewidth=2)
ln2 = ax1.plot(rondas, epsilon_cummulative_lp, color=color1, label='Epsilon acumulado', linestyle='--', linewidth=2)
ln3 = ax1.plot(rondas, accuracies_static, color=color2, label='Accuracy (%)', linewidth=2)
ln4 = ax1.plot(rondas, epsilon_cummulative_static, color=color2, label='Epsilon acumulado', linestyle='--', linewidth=2)
ax1.tick_params(axis='y', labelcolor='black')
ax1.set_ylim(0, 100)

lines = ln1 + ln3
labels = ["PD Optimizada", "PD Estatica"]
ax1.legend(lines, labels, loc='best')

fig.tight_layout()
plt.grid(True)
plt.savefig('Gaussian_CIFAR.png', dpi=300)

# %% [markdown]
# ####**RESULTADOS BACKDOOR**: Resultados para los tres conjuntos de datos

# %% [markdown]
# **MNIST**

# %%
df1 = pd.read_csv('metrics_DP_LP_mnist.csv')
df2 = pd.read_csv('metrics_DP_Static_mnist.csv')

rondas = df1['Round']
accuracies_lp = df1['Accuracy (%)']
epsilon_cummulative_lp= df1['Epsilon Acumulado']
asr_lp = df1['ASR']

accuracies_static = df2['Accuracy (%)']
epsilon_cummulative_static = df2['Epsilon Acumulado']
asr_static = df2['ASR']

plt.style.use(['science', 'no-latex'])
fig, ax1 = plt.subplots(figsize=(8, 5))

color1 = 'C0'
color2 = 'C3'
ax1.set_xlabel('Rondas')
ax1.set_ylabel('Accuracy (%) / Epsilon / ASR', color='black')
ln1 = ax1.plot(rondas, accuracies_lp, color=color1, label='Accuracy (%)', linewidth=2)
ln2 = ax1.plot(rondas, epsilon_cummulative_lp, color=color1, label='Epsilon acumulado', linestyle='--', linewidth=2)
ln3 = ax1.plot(rondas, asr_lp*100, color=color1, label='ASR', linestyle=':', linewidth=2)
ln4 = ax1.plot(rondas, accuracies_static, color=color2, label='Accuracy (%)', linewidth=2)
ln5 = ax1.plot(rondas, epsilon_cummulative_static, color=color2, label='Epsilon acumulado', linestyle='--', linewidth=2)
ln6 = ax1.plot(rondas, asr_static*100, color=color2, label='ASR', linestyle=':', linewidth=2)
ax1.tick_params(axis='y', labelcolor='black')
ax1.set_ylim(0, 100)

lines = ln1 + ln4
labels = ["PD Optimizada", "PD Estatica"]
ax1.legend(lines, labels, loc='best')

fig.tight_layout()
plt.grid(True)
plt.savefig('Backdoor_MNIST.png', dpi=300)

# %% [markdown]
# **FashionMNIST**

# %%
df1 = pd.read_csv('metrics_DP_LP_fashion.csv')
df2 = pd.read_csv('metrics_DP_Static_fashion.csv')

rondas = df1['Round']
accuracies_lp = df1['Accuracy (%)']
epsilon_cummulative_lp= df1['Epsilon Acumulado']
asr_lp = df1['ASR']

accuracies_static = df2['Accuracy (%)']
epsilon_cummulative_static = df2['Epsilon Acumulado']
asr_static = df2['ASR']

plt.style.use(['science', 'no-latex'])
fig, ax1 = plt.subplots(figsize=(8, 5))

color1 = 'C0'
color2 = 'C3'
ax1.set_xlabel('Rondas')
ax1.set_ylabel('Accuracy (%) / Epsilon / ASR', color='black')
ln1 = ax1.plot(rondas, accuracies_lp, color=color1, label='Accuracy (%)', linewidth=2)
ln2 = ax1.plot(rondas, epsilon_cummulative_lp, color=color1, label='Epsilon acumulado', linestyle='--', linewidth=2)
ln3 = ax1.plot(rondas, asr_lp*100, color=color1, label='ASR', linestyle=':', linewidth=2)
ln4 = ax1.plot(rondas, accuracies_static, color=color2, label='Accuracy (%)', linewidth=2)
ln5 = ax1.plot(rondas, epsilon_cummulative_static, color=color2, label='Epsilon acumulado', linestyle='--', linewidth=2)
ln6 = ax1.plot(rondas, asr_static*100, color=color2, label='ASR', linestyle=':', linewidth=2)
ax1.tick_params(axis='y', labelcolor='black')
ax1.set_ylim(0, 100)

lines = ln1 + ln4
labels = ["PD Optimizada", "PD Estatica"]
ax1.legend(lines, labels, loc='best')

fig.tight_layout()
plt.grid(True)
plt.savefig('Backdoor_fashion.png', dpi=300)

# %% [markdown]
# **CIFAR-10**

# %%
df1 = pd.read_csv('metrics_DP_LP_cifar.csv')
df2 = pd.read_csv('metrics_DP_Static_cifar.csv')

rondas = df1['Round']
accuracies_lp = df1['Accuracy (%)']
epsilon_cummulative_lp= df1['Epsilon Acumulado']
asr_lp = df1['ASR']

accuracies_static = df2['Accuracy (%)']
epsilon_cummulative_static = df2['Epsilon Acumulado']
asr_static = df2['ASR']

plt.style.use(['science', 'no-latex'])
fig, ax1 = plt.subplots(figsize=(8, 5))

color1 = 'C0'
color2 = 'C3'
ax1.set_xlabel('Rondas')
ax1.set_ylabel('Accuracy (%) / Epsilon / ASR', color='black')
ln1 = ax1.plot(rondas, accuracies_lp, color=color1, label='Accuracy (%)', linewidth=2)
ln2 = ax1.plot(rondas, epsilon_cummulative_lp, color=color1, label='Epsilon acumulado', linestyle='--', linewidth=2)
ln3 = ax1.plot(rondas, asr_lp*100, color=color1, label='ASR', linestyle=':', linewidth=2)
ln4 = ax1.plot(rondas, accuracies_static, color=color2, label='Accuracy (%)', linewidth=2)
ln5 = ax1.plot(rondas, epsilon_cummulative_static, color=color2, label='Epsilon acumulado', linestyle='--', linewidth=2)
ln6 = ax1.plot(rondas, asr_static*100, color=color2, label='ASR', linestyle=':', linewidth=2)
ax1.tick_params(axis='y', labelcolor='black')
ax1.set_ylim(0, 100)

lines = ln1 + ln4
labels = ["PD Optimizada", "PD Estatica"]
ax1.legend(lines, labels, loc='best')

fig.tight_layout()
plt.grid(True)
plt.savefig('Backdoor_CIFAR.png', dpi=300)

# %% [markdown]
# ####**RESULTADOS DMUG**: Resultados para MNIST

# %% [markdown]
# **Caso estático**

# %%
df1 = pd.read_csv('metrics_DP_Static_mnist.csv')

rondas = df1['Round']
accuracies_static = df1['Accuracy (%)']
epsilon_cummulative_static= df1['Epsilon Acumulado']
distances_static = df1['Distancia Minima']

plt.style.use(['science', 'no-latex'])
fig, ax1 = plt.subplots(figsize=(8, 5))
ax2 = ax1.twinx()

color1 = 'C0'
color2 = 'C1'
ax1.set_xlabel('Rondas')
ax1.set_ylabel('Accuracy (%) / Epsilon', color='black')
ax2.set_ylabel('Distancia Minima', color='black')
ln1 = ax1.plot(rondas, accuracies_static, color=color1, label='Accuracy (%)', linewidth=2)
ln2 = ax1.plot(rondas, epsilon_cummulative_static, color=color2, label='Epsilon acumulado', linestyle='--', linewidth=2)
ln3 = ax2.plot(rondas, distances_static, color=color3, label='Distancia Minima', linestyle=':', linewidth=2)
ax1.tick_params(axis='y', labelcolor='black')
ax1.set_ylim(0, 100)
ax2.set_ylim(min(distances_static), max(distances_static))

lines = ln1 + ln2 + ln3
labels = ["Accuracy (%)", "Epsilon acumulado", "Distancia Minima"]
ax1.legend(lines, labels, loc='upper right')

fig.tight_layout()
plt.grid(True)
plt.savefig('DMUG_static.png', dpi=300)

# %% [markdown]
# **Caso dinámico**

# %%
df1 = pd.read_csv('metrics_DP_LP_mnist.csv')

rondas = df1['Round']
accuracies_lp = df1['Accuracy (%)']
epsilon_cummulative_lp= df1['Epsilon Acumulado']
distances_lp = df1['Distancia Minima']

plt.style.use(['science', 'no-latex'])
fig, ax1 = plt.subplots(figsize=(8, 5))
ax2 = ax1.twinx()

color1 = 'C0'
color2 = 'C1'
color3 = 'C2'
ax1.set_xlabel('Rondas')
ax1.set_ylabel('Accuracy (%) / Epsilon', color='black')
ax2.set_ylabel('Distancia Minima', color='black')
ln1 = ax1.plot(rondas, accuracies_lp, color=color1, label='Accuracy (%)', linewidth=2)
ln2 = ax1.plot(rondas, epsilon_cummulative_lp, color=color2, label='Epsilon acumulado', linestyle='--', linewidth=2)
ln3 = ax2.plot(rondas, distances_lp, color=color3, label='Distancia Minima', linestyle=':', linewidth=2)
ax1.tick_params(axis='y', labelcolor='black')
ax1.set_ylim(0, 100)
ax2.set_ylim(min(distances_lp), max(distances_lp))

lines = ln1 + ln2 + ln3
labels = ["Accuracy (%)", "Epsilon acumulado", "Distancia Minima"]
ax1.legend(lines, labels, loc='upper right')

fig.tight_layout()
plt.grid(True)
plt.savefig('DMUG_optimized.png', dpi=300)

# %% [markdown]
# ####**RESULTADOS PARA EXPERIMENTO ADICIONAL VARIANDO EL NÚMERO DE ATACANTES**: Resultados para *Label Flipping* en MNIST, para *Backdoor* en FashionMNIST y para *Gaussian* en CIFAR-10

# %% [markdown]
# **Label Flipping MNIST - Aplicación estática**

# %%
df2 = pd.read_csv('metrics_DP_Static_2poisoned.csv')
df3 = pd.read_csv('metrics_DP_Static_3poisoned.csv')
df5 = pd.read_csv('metrics_DP_Static_5poisoned.csv')

rondas = df2['Round']
accuracies2 = df2['Accuracy (%)']
epsilon_cummulative2 = df2['Epsilon Acumulado']

accuracies3 = df3['Accuracy (%)']
epsilon_cummulative3 = df3['Epsilon Acumulado']

accuracies5 = df5['Accuracy (%)']
epsilon_cummulative5 = df5['Epsilon Acumulado']

plt.style.use(['science', 'no-latex'])
fig, ax1 = plt.subplots(figsize=(8, 5))

color1 = 'C3'
color2 = 'C1'
color3 = 'C4'
ax1.set_xlabel('Rondas')
ax1.set_ylabel('Accuracy (%) / Epsilon', color='black')
ln1 = ax1.plot(rondas, accuracies2, color=color1, label='Accuracy (%)', linewidth=2)
ln2 = ax1.plot(rondas, epsilon_cummulative2, color=color1, label='Epsilon acumulado', linestyle='--', linewidth=2)
ln3 = ax1.plot(rondas, accuracies3, color=color2, label='Accuracy (%)', linewidth=2)
ln4 = ax1.plot(rondas, epsilon_cummulative3, color=color2, label='Epsilon acumulado', linestyle='--', linewidth=2)
ln5 = ax1.plot(rondas, accuracies5, color=color3, label='Accuracy (%)', linewidth=2)
ln6 = ax1.plot(rondas, epsilon_cummulative5, color=color3, label='Epsilon acumulado', linestyle='--', linewidth=2)
ax1.tick_params(axis='y', labelcolor='black')
ax1.set_ylim(0, 100)

lines = ln1 + ln3  + ln5
labels = ["2 Adversarios", "3 Adversarios", "5 Adversarios"]
ax1.legend(lines, labels, loc='best')

fig.tight_layout()
plt.grid(True)
plt.savefig('LabelFlipping_poisoned_Static.png', dpi=300)

# %% [markdown]
# **Label Flipping MNIST - Aplicación dinámica**

# %%
df2 = pd.read_csv('metrics_DP_LP_2poisoned.csv')
df3 = pd.read_csv('metrics_DP_LP_3poisoned.csv')
df5 = pd.read_csv('metrics_DP_LP_5poisoned.csv')

rondas = df2['Round']
accuracies2 = df2['Accuracy (%)']
epsilon_cummulative2 = df2['Epsilon Acumulado']

accuracies3 = df3['Accuracy (%)']
epsilon_cummulative3 = df3['Epsilon Acumulado']

accuracies5 = df5['Accuracy (%)']
epsilon_cummulative5 = df5['Epsilon Acumulado']

plt.style.use(['science', 'no-latex'])
fig, ax1 = plt.subplots(figsize=(8, 5))

color1 = 'C3'
color2 = 'C1'
color3 = 'C4'
ax1.set_xlabel('Rondas')
ax1.set_ylabel('Accuracy (%) / Epsilon', color='black')
ln1 = ax1.plot(rondas, accuracies2, color=color1, label='Accuracy (%)', linewidth=2)
ln2 = ax1.plot(rondas, epsilon_cummulative2, color=color1, label='Epsilon acumulado', linestyle='--', linewidth=2)
ln3 = ax1.plot(rondas, accuracies3, color=color2, label='Accuracy (%)', linewidth=2)
ln4 = ax1.plot(rondas, epsilon_cummulative3, color=color2, label='Epsilon acumulado', linestyle='--', linewidth=2)
ln5 = ax1.plot(rondas, accuracies5, color=color3, label='Accuracy (%)', linewidth=2)
ln6 = ax1.plot(rondas, epsilon_cummulative5, color=color3, label='Epsilon acumulado', linestyle='--', linewidth=2)
ax1.tick_params(axis='y', labelcolor='black')
ax1.set_ylim(0, 100)

lines = ln1 + ln3  + ln5
labels = ["2 Adversarios", "3 Adversarios", "5 Adversarios"]
ax1.legend(lines, labels, loc='best')

fig.tight_layout()
plt.grid(True)
plt.savefig('LabelFlipping_poisoned_LP.png', dpi=300)

# %% [markdown]
# **Backdoor FashionMNIST - Aplicación estática**

# %%
df2 = pd.read_csv('metrics_DP_Static_3poisoned.csv')
df3 = pd.read_csv('metrics_DP_Static_4poisoned.csv')
df5 = pd.read_csv('metrics_DP_Static_5poisoned.csv')

rondas = df2['Round']
accuracies2 = df2['Accuracy (%)']
epsilon_cummulative2 = df2['Epsilon Acumulado']

accuracies3 = df3['Accuracy (%)']
epsilon_cummulative3 = df3['Epsilon Acumulado']

accuracies5 = df5['Accuracy (%)']
epsilon_cummulative5 = df5['Epsilon Acumulado']

plt.style.use(['science', 'no-latex'])
fig, ax1 = plt.subplots(figsize=(8, 5))

color1 = 'C3'
color2 = 'C1'
color3 = 'C4'
ax1.set_xlabel('Rondas')
ax1.set_ylabel('Accuracy (%) / Epsilon', color='black')
ln1 = ax1.plot(rondas, accuracies2, color=color1, label='Accuracy (%)', linewidth=2)
ln2 = ax1.plot(rondas, epsilon_cummulative2, color=color1, label='Epsilon acumulado', linestyle='--', linewidth=2)
ln3 = ax1.plot(rondas, accuracies3, color=color2, label='Accuracy (%)', linewidth=2)
ln4 = ax1.plot(rondas, epsilon_cummulative3, color=color2, label='Epsilon acumulado', linestyle='--', linewidth=2)
ln5 = ax1.plot(rondas, accuracies5, color=color3, label='Accuracy (%)', linewidth=2)
ln6 = ax1.plot(rondas, epsilon_cummulative5, color=color3, label='Epsilon acumulado', linestyle='--', linewidth=2)
ax1.tick_params(axis='y', labelcolor='black')
ax1.set_ylim(0, 100)

lines = ln1 + ln3  + ln5
labels = ["3 Adversarios", "4 Adversarios", "5 Adversarios"]
ax1.legend(lines, labels, loc='best')

fig.tight_layout()
plt.grid(True)
plt.savefig('Backdoor_poisoned_Static.png', dpi=300)

# %% [markdown]
# **Backdoor FashionMNIST - Aplicación dinámica**

# %%
df2 = pd.read_csv('metrics_DP_LP_3poisoned.csv')
df3 = pd.read_csv('metrics_DP_LP_4poisoned.csv')
df5 = pd.read_csv('metrics_DP_LP_5poisoned.csv')

rondas = df2['Round']
accuracies2 = df2['Accuracy (%)']
epsilon_cummulative2 = df2['Epsilon Acumulado']

accuracies3 = df3['Accuracy (%)']
epsilon_cummulative3 = df3['Epsilon Acumulado']

accuracies5 = df5['Accuracy (%)']
epsilon_cummulative5 = df5['Epsilon Acumulado']

plt.style.use(['science', 'no-latex'])
fig, ax1 = plt.subplots(figsize=(8, 5))

color1 = 'C3'
color2 = 'C1'
color3 = 'C4'
ax1.set_xlabel('Rondas')
ax1.set_ylabel('Accuracy (%) / Epsilon', color='black')
ln1 = ax1.plot(rondas, accuracies2, color=color1, label='Accuracy (%)', linewidth=2)
ln2 = ax1.plot(rondas, epsilon_cummulative2, color=color1, label='Epsilon acumulado', linestyle='--', linewidth=2)
ln3 = ax1.plot(rondas, accuracies3, color=color2, label='Accuracy (%)', linewidth=2)
ln4 = ax1.plot(rondas, epsilon_cummulative3, color=color2, label='Epsilon acumulado', linestyle='--', linewidth=2)
ln5 = ax1.plot(rondas, accuracies5, color=color3, label='Accuracy (%)', linewidth=2)
ln6 = ax1.plot(rondas, epsilon_cummulative5, color=color3, label='Epsilon acumulado', linestyle='--', linewidth=2)
ax1.tick_params(axis='y', labelcolor='black')
ax1.set_ylim(0, 100)

lines = ln1 + ln3  + ln5
labels = ["3 Adversarios", "4 Adversarios", "5 Adversarios"]
ax1.legend(lines, labels, loc='best')

fig.tight_layout()
plt.grid(True)
plt.savefig('Backdoor_poisoned_LP.png', dpi=300)

# %% [markdown]
# **Gaussian CIFAR-10 - Aplicación estática**

# %%
df2 = pd.read_csv('metrics_DP_Static_2poisoned.csv')
df3 = pd.read_csv('metrics_DP_Static_3poisoned.csv')
df5 = pd.read_csv('metrics_DP_Static_5poisoned.csv')

rondas = df2['Round']
accuracies2 = df2['Accuracy (%)']
epsilon_cummulative2 = df2['Epsilon Acumulado']

accuracies3 = df3['Accuracy (%)']
epsilon_cummulative3 = df3['Epsilon Acumulado']

accuracies5 = df5['Accuracy (%)']
epsilon_cummulative5 = df5['Epsilon Acumulado']

plt.style.use(['science', 'no-latex'])
fig, ax1 = plt.subplots(figsize=(8, 5))

color1 = 'C1'
color2 = 'C2'
color3 = 'C4'
ax1.set_xlabel('Rondas')
ax1.set_ylabel('Accuracy (%) / Epsilon', color='black')
ln1 = ax1.plot(rondas, accuracies2, color=color1, label='Accuracy (%)', linewidth=2)
ln2 = ax1.plot(rondas, epsilon_cummulative2, color=color1, label='Epsilon acumulado', linestyle='--', linewidth=2)
ln3 = ax1.plot(rondas, accuracies3, color=color2, label='Accuracy (%)', linewidth=2)
ln4 = ax1.plot(rondas, epsilon_cummulative3, color=color2, label='Epsilon acumulado', linestyle='--', linewidth=2)
ln5 = ax1.plot(rondas, accuracies5, color=color3, label='Accuracy (%)', linewidth=2)
ln6 = ax1.plot(rondas, epsilon_cummulative5, color=color3, label='Epsilon acumulado', linestyle='--', linewidth=2)
ax1.tick_params(axis='y', labelcolor='black')
ax1.set_ylim(0, 100)

lines = ln1 + ln3  + ln5
labels = ["2 Adversarios", "3 Adversarios", "5 Adversarios"]
ax1.legend(lines, labels, loc='best')

fig.tight_layout()
plt.grid(True)
plt.savefig('Gaussian_poisoned_Static.png', dpi=300)

# %% [markdown]
# **Gaussian CIFAR-10 - Aplicación dinámica**

# %%
df2 = pd.read_csv('metrics_DP_LP_2poisoned.csv')
df3 = pd.read_csv('metrics_DP_LP_3poisoned.csv')
df5 = pd.read_csv('metrics_DP_LP_5poisoned.csv')

rondas = df2['Round']
accuracies2 = df2['Accuracy (%)']
epsilon_cummulative2 = df2['Epsilon Acumulado']

accuracies3 = df3['Accuracy (%)']
epsilon_cummulative3 = df3['Epsilon Acumulado']

accuracies5 = df5['Accuracy (%)']
epsilon_cummulative5 = df5['Epsilon Acumulado']

plt.style.use(['science', 'no-latex'])
fig, ax1 = plt.subplots(figsize=(8, 5))

color1 = 'C1'
color2 = 'C2'
color3 = 'C4'
ax1.set_xlabel('Rondas')
ax1.set_ylabel('Accuracy (%) / Epsilon', color='black')
ln1 = ax1.plot(rondas, accuracies2, color=color1, label='Accuracy (%)', linewidth=2)
ln2 = ax1.plot(rondas, epsilon_cummulative2, color=color1, label='Epsilon acumulado', linestyle='--', linewidth=2)
ln3 = ax1.plot(rondas, accuracies3, color=color2, label='Accuracy (%)', linewidth=2)
ln4 = ax1.plot(rondas, epsilon_cummulative3, color=color2, label='Epsilon acumulado', linestyle='--', linewidth=2)
ln5 = ax1.plot(rondas, accuracies5, color=color3, label='Accuracy (%)', linewidth=2)
ln6 = ax1.plot(rondas, epsilon_cummulative5, color=color3, label='Epsilon acumulado', linestyle='--', linewidth=2)
ax1.tick_params(axis='y', labelcolor='black')
ax1.set_ylim(0, 100)

lines = ln1 + ln3  + ln5
labels = ["2 Adversarios", "3 Adversarios", "5 Adversarios"]
ax1.legend(lines, labels, loc='best')

fig.tight_layout()
plt.grid(True)
plt.savefig('Gaussian_poisoned_LP.png', dpi=300)
